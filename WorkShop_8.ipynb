# %% [markdown]
# <a href="https://colab.research.google.com/github/Princebhagat001/CM_workshop1.py/blob/main/WorkShop_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prince Bhagat

# %%
import numpy as np

import matplotlib.pyplot as plt

""" Part 1 - Problem 1: Solve linear systems graphically. """

# Generate 100 equidistant point between -5 to 5 for x

x = np.linspace(-5,5,100)

## Calculate y values for Equation 1 and 2

y1 = (5-x)/3

y2 = (5+x)/2

y3 = 3-x

## Generate a figure frame for plotting the lines

fig, ax = plt.subplots()

## Plot the two lines

ax.plot(x,y1, color='r')

ax.plot(x,y2, color='g')

ax.plot(x,y3, color='b')

## To decorate the plot, we insert equations.

ax.text(0.5,0.6, '$x+3y = 5$', color='r')

ax.text(-3,0.5,'$x-2y = -5$', color='g')

ax.text(1.2,2, '$x+y = 3$', color='b')

## Set the limits of the X & Y axes.

ax.set_xlim(-4,4)

ax.set_ylim(-2,6)

## Set property of X and Y axes, e.g., color and linewidth

ax.axvline(color='k',linewidth = 1)

ax.axhline(color='k',linewidth = 1)

## This option specifies the ticks based the list of numbers provided.

ax.set_xticks(list(range(-4,5)))

ax.set_aspect('equal')

ax.grid(True,ls=':')

plt.xlabel("X")

plt.ylabel("Y")

plt.show()

# %%
# Task 1
import numpy as np
import matplotlib.pyplot as plt
# Generate 100 equidistant point between -5 to 5 for x
x = np.linspace(-5,5,100)
## Calculate y values for Equation 1 and 2
y1 = (3-2*x)/3
y2 = (6-4*x)/6
y3 = (3*x-1)/2
## Generate a figure frame for plotting the lines
fig, ax = plt.subplots()
## Plot the two lines
ax.plot(x,y1, color='r')
ax.plot(x,y2, color='g')
ax.plot(x,y3, color='b')
## To decorate the plot, we insert equations.
ax.text(0.5,0.6, 'x+3y=5', color='r')
ax.text(-3,0.5,'x-2y=-5', color='g')
ax.text(1.2,2, 'x+y=3', color='b')
## Set the limits of the X & Y axes.
ax.set_xlim(-4,4)
ax.set_ylim(-2,6)
## Set property of X and Y axes, e.g., color and linewidth
ax.axvline(color='k',linewidth = 1)
ax.axhline(color='k',linewidth = 1)
## This option specifies the ticks based the list of numbers provided.
ax.set_xticks(list(range(-4,5)))
ax.set_aspect('equal')
ax.grid(True,ls=':')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
# Task 2 A
import numpy as np
A = np.random.randint(1,10,(5,6))
B = np.random.randint(1,10,(5,6))
C = A + B
print("Matrix A:\n", A)
print("Matrix B:\n", B)
print("Result (A+B):\n", C)
# Out:
# Matrix A:
#  [[6 7 7 6 6 5]
#  [1 9 7 2 9 8]
#  [8 3 9 6 1 8]
#  [6 9 4 1 7 4]
#  [3 3 1 9 5 2]]
# Matrix B:
#  [[6 5 7 3 2 2]
#  [9 6 8 7 6 5]
#  [1 3 4 9 7 4]
#  [8 9 1 5 2 9]
#  [5 3 1 8 6 9]]
# Result (A+B):
#  [[12 12 14  9  8  7]
#  [10 15 15  9 15 13]
#  [ 9  6 13 15  8 12]
#  [14 18  5  6  9 13]
#  [ 8  6  2 17 11 11]]

# %%
# Task 2 B
A = np.random.randint(1,10,(2,3))
B = np.random.randint(1,10,(2,3))
C = np.random.randint(1,10,(2,3))
result = A - B + C
print(A, B, C, result)
# Out:
# [[9 8 9]
#  [6 3 8]] [[9 3 6]
#  [1 9 2]] [[2 6 3]
#  [9 9 6]] [[ 2 11  6]
#  [14  3 12]]

# %%
# Task C
A = np.random.randint(1,21,(4,4))
print(A)
num = int(input("Enter number: "))
count = np.sum(A == num)
if count > 0:
    print("Found", count, "times")
else:
    print("Not found")
# Out:
# [[15 14 13  8]
#  [11  1  3  1]
#  [ 2  7 16 16]
#  [11 19 16  9]]
# Enter number: 5
# Not found

# %%
import numpy as np
a = np.array([[1, 2], [3, 4]])
det = np.linalg.det(a)
print("Determinant:", det)
# Out:
# Determinant: -2.0000000000000004

# %%
rank = np.linalg.matrix_rank(a)
print("Rank:", rank)
# Out:
# Rank: 2

# %%
inv = np.linalg.inv(a)
print("Inverse:\n", inv)
# Out:
# Inverse:
#  [[-2.   1. ]
#  [ 1.5 -0.5]]

# %%
b = np.array([1, 2])
x = np.linalg.solve(a, b)
print("Solution:", x)
# Out:
# Solution: [0.  0.5]

# %%
import numpy as np
a = np.random.randn(3, 2)
b = np.linalg.pinv(a)
result = np.allclose(a, np.dot(a, np.dot(b, a)))
print("Check A A+ A = A:", result)
# Out:
# Check A A+ A = A: True

# %%
#Task 3 A
import numpy as np
A = np.random.randint(1, 20, (5, 5))
print("Matrix A:\n", A)
rank = np.linalg.matrix_rank(A)
print("Rank of A:", rank)
det = np.linalg.det(A)
print("Determinant of A:", det)
if rank == 5 and det != 0:
    print("Matrix is invertible")
else:
    print("Matrix is NOT invertible")
# Out:
# Matrix A:
#  [[16 10  5 16 17]
#  [ 1  7  2 15  4]
#  [14  2 19  8 17]
#  [12  4 12  1 11]
#  [ 6 11  5 14  8]]
# Rank of A: 5
# Determinant of A: -14966.000000000002
# Matrix is invertible

# %%
#Task 3 B
A = np.random.rand(5,5)
x = np.random.rand(5)
b = np.dot(A, x)
x_sol = np.linalg.solve(A, b)
print(x_sol)
# Out:
# [0.53701765 0.19840217 0.00894514 0.05214123 0.48658759]

# %%
#Task 3 C
import numpy as np
A = np.array([
    [8, 3, -2],
    [-4, 7, 5],
    [3, 4, -12]
])
b = np.array([9, 15, 35])
x = np.linalg.solve(A, b)
print("Solution:", x)
# Out:
# Solution: [-0.58226371  3.22870478 -1.98599767]

# %%
#Task 4
import numpy as np
import matplotlib.pyplot as plt
x = np.array([3,2,1,0,1,2,3,4,5,7])
y = np.array([7.6,1,4.8,5,2.8,0.6,4,6.2,6,6.4])
coeffs = np.polyfit(x, y, 2)
poly = np.poly1d(coeffs)
x_line = np.linspace(min(x), max(x), 100)
y_line = poly(x_line)
plt.scatter(x, y)
plt.plot(x_line, y_line)
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.show()
print("Polynomial:", poly)
# Out:
# Polynomial:          2
# 0.06667 x + 0.06667 x + 3.467
